# %% [markdown]
# **CarPurchasing using OOP's concepts and Multiple LinearRegression**

# %%
'''
In this we are going to develop the Multiple Linear Regression using Oops concet for CarPurchasing_data set and predict the prize and calculate accuracy and loss
'''
import numpy as np
import pandas as pd
import sklearn
import sys
import math
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

class CarPurchase:
  def __init__(self,location):
    try:
      self.location=location.drop(['Customer Name','Customer e-mail','Country'],axis=1)
      self.X=self.location.iloc[: ,:-1]
      self.y=self.location.iloc[: ,-1]
      self.X_train,self.X_test,self.y_train,self.y_test=train_test_split(self.X,self.y,test_size=0.2,random_state=42)
    except Exception as e:
      error_type, error_msg, err_line = sys.exc_info()
      print(f"Error from Line {err_line.tblineno} -> type {error_type.__name__} -> Error msg -> {error_msg}")
  def Training_data(self):
    try:
      self.reg=LinearRegression()
      self.reg.fit(self.X_train,self.y_train)
      self.Training_data=pd.DataFrame()
      Training_data=X_train.copy()
      Training_data['Car prize Annual']=y_train.copy()
      Training_data['Car prize Predicted Annual']=y_train_pred

    except FileNotFoundError:
      print("Error: File not found.")
    except Exception as e:
      error_type, error_msg, err_line = sys.exc_info()
      print(f"Error from Line {err_line.tblineno} -> type {error_type.__name__} -> Error msg -> {error_msg}")
  def r2_score_cal_train(self):# formula for r2_socre is : 1-(((y_train-y_train_pred)**2)/(y_train-mean of y_train)**2)
    try:
      sum_actual = 0
      count = 0
      for i in Training_data.index:
        sum_actual += Training_data['Actual Car Price'][i]
        count += 1
        mean_actual = sum_actual / count
        sum_squared_diff = 0
      for k in Training_data.index:
        r2_score_value=(1-((Training_data['Actual Car Price'][k]-Training_data['Predicted Car Price'][k])**2)/((Training_data['Actual Car Price'][k]-mean_actual)**2))
      print(f'Train data r2_score means the Accuracy is calculate manually : {r2_score_value}')
    except Exception as e:
      error_type, error_msg, err_line = sys.exc_info()
      print(f"Error from Line {err_line.tblineno} -> type {error_type.__name__} -> Error msg -> {error_msg}")
  def Mean_Sqr_Err_train(self): # formula for mean_square_error is: 1/n*((y_tain-y_train_pred)**2)
    try:
      self.count=len(Training_data)
      for i in Training_data.index:
        self.MSE=(1/self.count*((Training_data['Actual Car Price'][i]-Training_data['Predicted Car Price'][i])**2))*100
      print(f'Mean square error is calculate manually : {self.MSE}')
    except Exception as e:
        error_type, error_msg, err_line = sys.exc_info()
        print(f"Error from Line {err_line.tblineno} -> type {error_type.__name__} -> Error msg -> {error_msg}")
  def Root_Mean_sqr_Err_Train(self): # formula for root_mean_sqaure_error is : square_root(mean_square_error)
    try:
      self.RMSE=math.sqrt(self.MSE)
      print(f'Root Mean Square Error in Train is calculated manually :{self.RMSE}')
    except Exception as e:
      error_type, error_msg, err_line = sys.exc_info()
      print(f"Error from Line {err_line.tblineno} -> type {error_type.__name__} -> Error msg -> {error_msg}")
  def Absolute_MSE(self): # formula for absolute_mean_square_error is : 1/n * |y_train-y_train_pred|
    try:
      self.sum_square_error=0
      for i in Training_data.index:
        self.square_error=abs(Training_data['Actual Car Price'][i]-Training_data['Predicted Car Price'][i])**2
        self.sum_square_error+=self.square_error
      self.AMSE=(1/len(Training_data))* self.sum_square_error
      print(f'Absolute Mean Square Error is calculate Manually : {self.AMSE}')
    except Exception as e:
      error_type, error_msg, err_line = sys.exc_info()
      print(f"Error from Line {err_line.tblineno} -> type {error_type.__name__} -> Error msg -> {error_msg}")

  def Training_Performance(self):
    try:
      self.y_train_pred=self.reg.predict(self.X_train)
      print(f'Train Accuracy with r2_score fun is :{r2_score(self.y_train,self.y_train_pred)}')
      print(f'Train Loss with MSE fun is : {mean_squared_error(self.y_train,self.y_train_pred)}')
    except Exception as e:
      error_type, error_msg, err_line = sys.exc_info()
      print(f"Error from Line {err_line.tblineno} -> type {error_type.__name__} -> Error msg -> {error_msg}")
  def Testing_Performance(self):
    try:
      self.y_test_pred=self.reg.predict(self.X_test)
      print(f'Test Accuracy with functions is : {r2_score(self.y_test,self.y_test_pred)}')
      print(f'Test Loss is with functions is : {mean_squared_error(self.y_test,self.y_test_pred)}')
    except Exception as e:
      error_type, error_msg, err_line = sys.exc_info()
      print(f"Error from Line {err_line.tblineno} -> type {error_type.__name__} -> Error msg -> {error_msg}")
  def evaluate_test_data(self):
    try:
      y_test_pred = reg.predict(X_test)
      Testing_data=pd.DataFrame()
      Testing_data=X_test.copy()
      Testing_data['Actual Price']=y_test.copy()
      Testing_data['Predicted Price']=y_test_pred
      count = len(y_test_pred)
      sum_actual = y_test_pred.sum()
      mean_actual = sum_actual / count
      sum_squared_diff = 0
      for i in Testing_data.index:
        r2_score_value=(1-((Testing_data['Actual Price'][i]-Testing_data['Predicted Price'][i])**2)/((Testing_data['Actual Price'][i]-mean_actual)**2))
      print(f'Test data r2_score (Accuracy) calculated manually: {r2_score_value}')
      count_test=len(Testing_data)
      square_error=0
      mean_sqr_error=0
      for j in Testing_data.index:
        square_error=((Testing_data['Actual Price'][j]-Testing_data['Predicted Price'][j])**2)
        mean_sqr_error+=square_error
      MSE_test=1/(len(Testing_data))*mean_sqr_error
      print(f'Mean Square Error (Test) calculated manually: {MSE_test}')
      rmse = math.sqrt(MSE_test)
      print(f'Root Mean Square Error (Test) calculated manually: {rmse}')
      self.sum_square_error = 0
      for k in Testing_data.index:
        self.square_error=abs(Testing_data['Actual Price'][k]-Testing_data['Predicted Price'][k])**2
        self.sum_square_error+=self.square_error
      self.AMSE=(1/len(Testing_data))* self.sum_square_error
      print(f'Absolute Mean Square Error (Test) calculated manually: {self.AMSE}')
    except Exception as e:
              error_type, error_msg, err_line = sys.exc_info()
              print(f"Error from Line {err_line.tblineno} -> type {error_type.__name__} -> Error msg -> {error_msg}")

if __name__=='__main__':
  try:
    obj=CarPurchase(location = pd.read_csv('Car_Purchasing_Data.csv', encoding='latin-1'))
    print(f'Traning data Performance:')
    print()
    obj.Training_data()
    obj.Training_Performance()
    obj.r2_score_cal_train()
    obj.Mean_Sqr_Err_train()
    obj.Root_Mean_sqr_Err_Train()
    obj.Absolute_MSE()
    print()
    print(f'Testing data Performance:')
    print()
    obj.Testing_Performance()
    obj.evaluate_test_data()
  except Exception as e:
    error_type, error_msg, err_line = sys.exc_info()
    print(f"Error from Line {err_line.tblineno} -> type {error_type.__name__} -> Error msg -> {error_msg}")
# Out:
# Traning data Performance:
#
# Train Accuracy with r2_score fun is :0.9999999812764105
# Train Loss with MSE fun is : 2.1990016683893954
# Train data r2_score means the Accuracy is calculate manually : 0.9999999169519312
# Mean square error is calculate manually : 2.2049242371757685
# Root Mean Square Error in Train is calculated manually :1.484898729602719
# Absolute Mean Square Error is calculate Manually : 2.199001668389395
#
# Testing data Performance:
#
# Test Accuracy with functions is : 0.9999999806028682
# Test Loss is with functions is : 2.0943696031557573
# Test data r2_score (Accuracy) calculated manually: 0.9999998837487859
# Mean Square Error (Test) calculated manually: 2.094369603155757
# Root Mean Square Error (Test) calculated manually: 1.4471936992523693
# Absolute Mean Square Error (Test) calculated manually: 2.094369603155757
